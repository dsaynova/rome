# %% [markdown]
# # Evaluation
# On the fact recall dataset.

# %%
import pandas as pd
from sklearn import metrics

# %% [markdown]
# ## Load the fact recall dataset

# %%
fact_recall_data = pd.read_json("/cephyr/users/lovhag/Alvis/projects/fact-recall-detection/data/data_creation/final_splits/confident_fact_recall_preds.jsonl", lines=True)
# for some reason, there are duplicates?
fact_recall_data = fact_recall_data[~fact_recall_data.duplicated()]

fact_recall_data.head()
# Out:
#    obj_label            sub_label predicate_id    source  sub_view_rates  \
# 0  Jerusalem  Obadiah ben Abraham          P20  TREx_UHN      261.166667
# 1  Jerusalem  Obadiah ben Abraham          P20  TREx_UHN      261.166667
# 2  Jerusalem  Obadiah ben Abraham          P20  TREx_UHN      261.166667
# 3  Jerusalem  Obadiah ben Abraham          P20  TREx_UHN      261.166667
# 4  Jerusalem  Obadiah ben Abraham          P20  TREx_UHN      261.166667
#
#    obj_view_rates  string_match  person_name  \
# 0   165070.916667         False        False
# 1   165070.916667         False        False
# 2   165070.916667         False        False
# 3   165070.916667         False        False
# 4   165070.916667         False        False
#
#                                    prompt                    template  \
# 0             Obadiah ben Abraham died in             [X] died in [Y]
# 1             Obadiah ben Abraham died at             [X] died at [Y]
# 2      Obadiah ben Abraham passed away in      [X] passed away in [Y]
# 3      Obadiah ben Abraham passed away at      [X] passed away at [Y]
# 4  Obadiah ben Abraham lost their life at  [X] lost their life at [Y]
#
#       answers  p_answers  pred_rank  prompt_bias  correct  surface_pred  \
# 0   Jerusalem   0.048551          1        False     True         False
# 1   Jerusalem   0.075843          1        False     True         False
# 2   Jerusalem   0.064481          1        False     True         False
# 3   Jerusalem   0.026302          2        False     True         False
# 4   Jerusalem   0.056528          1        False     True         False
#
#    trivial_pred  consistency_counts
# 0         False                   6
# 1         False                   6
# 2         False                   6
# 3         False                   6
# 4         False                   6

# %%
len(fact_recall_data)
# Out:
# 1602

# %% [markdown]
# ## Load the TE based data

# %%
data = pd.read_csv("/cephyr/users/lovhag/Alvis/projects/rome/data/fact_recall_detection/gpt2_xl_final.csv")
data.head()
# Out:
#                subject    template       pred  pred_rank correct_answer  \
# 0  Obadiah ben Abraham  {} died in        the          0      Jerusalem
# 1  Obadiah ben Abraham  {} died in  Jerusalem          1      Jerusalem
# 2  Obadiah ben Abraham  {} died in          5          2      Jerusalem
# 3  Obadiah ben Abraham  {} died in          6          3      Jerusalem
# 4  Obadiah ben Abraham  {} died in         12          4      Jerusalem
#
#          te
# 0  0.030592
# 1  0.031775
# 2  0.018109
# 3  0.012320
# 4  0.016043

# %% [markdown]
# Apply the same filtering here as for the fact recall data. Only keep the top 3 model predictions.

# %%
data = data[data.pred_rank<3]
len(data)
# Out:
# 4824

# %%
forbidden_predictions = ["a", "the", "collaboration", "response", "public", '"', "order", "partnership", "honor", "AD", "open", "H", "age", "creating", "disgrace", "her", "his", "in", "left", "not", "providing", "tragedy", "which", "whom"]
forbidden_mask = (data.pred.isin(forbidden_predictions))
data["trivial_pred"] = forbidden_mask

te_thresh = 0.1
data["te_fact_recall"] = (data.te>te_thresh) & ~(data.trivial_pred)
print(f"{sum(data.te_fact_recall)} data samples have a TE above 0.1")
# Out:
# 1048 data samples have a TE above 0.1

# %% [markdown]
# Reformat the dataset to make it compatible with the gold labels dataset

# %%
data["template"] = data.template.apply(lambda val: val.replace("{}", "[X]")+" [Y]")
data["pred"] = data.pred.apply(lambda val: " "+val)
data = data.rename(columns={"subject": "sub_label", "pred": "answers"})

# for some reason, there are duplicates?
data = data[~data.duplicated()]

data
# Out:
#                  sub_label                              template     answers  \
# 0      Obadiah ben Abraham                       [X] died in [Y]         the
# 1      Obadiah ben Abraham                       [X] died in [Y]   Jerusalem
# 2      Obadiah ben Abraham                       [X] died in [Y]           5
# 10     Obadiah ben Abraham                       [X] died at [Y]         the
# 11     Obadiah ben Abraham                       [X] died at [Y]   Jerusalem
# ...                    ...                                   ...         ...
# 16061               Topeka       [X], that is the capital of [Y]         the
# 16062               Topeka       [X], that is the capital of [Y]    Arkansas
# 16070               Topeka  [X], that is the capital city of [Y]      Kansas
# 16071               Topeka  [X], that is the capital city of [Y]         the
# 16072               Topeka  [X], that is the capital city of [Y]     Johnson
#
#        pred_rank correct_answer        te  trivial_pred  te_fact_recall
# 0              0      Jerusalem  0.030592          True           False
# 1              1      Jerusalem  0.031775         False           False
# 2              2      Jerusalem  0.018109         False           False
# 10             0      Jerusalem -0.003685          True           False
# 11             1      Jerusalem  0.058086         False           False
# ...          ...            ...       ...           ...             ...
# 16061          1         Kansas -0.134828          True           False
# 16062          2         Kansas  0.004054         False           False
# 16070          0         Kansas  0.744173         False            True
# 16071          1         Kansas -0.141578          True           False
# 16072          2         Kansas  0.004523         False           False
#
# [4806 rows x 8 columns]

# %% [markdown]
# ## Compare the sets

# %%
gold_fact_recall = []
for ix, row in data.iterrows():
    is_fact_recall = (row[["sub_label", "template", "answers"]] == fact_recall_data[["sub_label","template","answers"]]).all(axis=1).sum()
    is_fact_recall = is_fact_recall==1
    gold_fact_recall.append(is_fact_recall)
    
data["gold_fact_recall"] = gold_fact_recall
data.head()
# Out:
#               sub_label         template     answers  pred_rank  \
# 0   Obadiah ben Abraham  [X] died in [Y]         the          0
# 1   Obadiah ben Abraham  [X] died in [Y]   Jerusalem          1
# 2   Obadiah ben Abraham  [X] died in [Y]           5          2
# 10  Obadiah ben Abraham  [X] died at [Y]         the          0
# 11  Obadiah ben Abraham  [X] died at [Y]   Jerusalem          1
#
#    correct_answer        te  trivial_pred  te_fact_recall  gold_fact_recall
# 0       Jerusalem  0.030592          True           False             False
# 1       Jerusalem  0.031775         False           False              True
# 2       Jerusalem  0.018109         False           False             False
# 10      Jerusalem -0.003685          True           False             False
# 11      Jerusalem  0.058086         False           False              True

# %%
sum(gold_fact_recall)
# Out:
# 1602

# %%
data.value_counts(["te_fact_recall", "gold_fact_recall"])
# Out:
# te_fact_recall  gold_fact_recall
# False           False               3091
# True            True                 931
# False           True                 671
# True            False                113
# dtype: int64

# %%
metrics
